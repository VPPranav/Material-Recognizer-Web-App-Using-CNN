# %%
# Cell 1: Imports and Dataset Loading (with trash class removal)
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

image_size = 96
X = []
y = []

# ✅ Use relative path assuming "dataset-resized" is in the current working directory
data_dir = "dataset-resized"

for label in os.listdir(data_dir):
    if label.lower() == 'trash':
        continue
    class_path = os.path.join(data_dir, label)
    if not os.path.isdir(class_path):
        continue
    for file in os.listdir(class_path):
        img_path = os.path.join(class_path, file)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (image_size, image_size))
            X.append(img)
            y.append(label)

X = np.array(X).astype('float32') / 255.0
y = np.array(y)

print(f"Loaded {len(X)} images")
print("Classes found (without trash):", np.unique(y))

# Label Encoding and Train-Test Split
le = LabelEncoder()
y_encoded = le.fit_transform(y)
y_cat = to_categorical(y_encoded)

X_train, X_test, y_train, y_test = train_test_split(
    X, y_cat, test_size=0.2, stratify=y_encoded, random_state=42
)

print(f"Train: {X_train.shape}, Test: {X_test.shape}")
print("Encoded classes:", le.classes_)
# Out:
# Loaded 2189 images
# Classes found (without trash): ['cardboard' 'glass' 'metal' 'paper' 'plastic']
# Train: (1751, 96, 96, 3), Test: (438, 96, 96, 3)
# Encoded classes: ['cardboard' 'glass' 'metal' 'paper' 'plastic']

# %%
# Cell 2: Data Augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=15,
    zoom_range=0.1,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(X_train)

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.losses import Loss

class FocalLoss(Loss):
    def __init__(self, gamma=2.0, alpha=0.25, **kwargs):
        super(FocalLoss, self).__init__(**kwargs)
        self.gamma = gamma
        self.alpha = alpha

    def call(self, y_true, y_pred):
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * K.log(y_pred)
        weight = self.alpha * K.pow(1 - y_pred, self.gamma)
        return K.mean(weight * cross_entropy, axis=-1)

# %%
# Cell 3: MobileNetV2-based Transfer Learning Model
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam

# Load MobileNetV2 without top classifier
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(96, 96, 3))

# Freeze base model initially
base_model.trainable = False

# Add custom head
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(5, activation='softmax')(x)

# Final model
model = Model(inputs=base_model.input, outputs=output)

# Compile with Focal Loss
model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss=FocalLoss(gamma=2.0, alpha=0.25),
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 96, 96, 3)         │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1 (Conv2D)                │ (None, 48, 48, 32)        │             864 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ bn_Conv1 (BatchNormalization) │ (None, 48, 48, 32)        │             128 │ Conv1[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv1_relu (ReLU)             │ (None, 48, 48, 32)        │               0 │ bn_Conv1[0][0]             │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_depthwise       │ (None, 48, 48, 32)        │             288 │ Conv1_relu[0][0]           │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_depthwise_BN    │ (None, 48, 48, 32)        │             128 │ expanded_conv_depthwise[0… │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_depthwise_relu  │ (None, 48, 48, 32)        │               0 │ expanded_conv_depthwise_B… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_project         │ (None, 48, 48, 16)        │             512 │ expanded_conv_depthwise_r… │
# │ (Conv2D)                      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ expanded_conv_project_BN      │ (None, 48, 48, 16)        │              64 │ expanded_conv_project[0][… │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_expand (Conv2D)       │ (None, 48, 48, 96)        │           1,536 │ expanded_conv_project_BN[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_expand_BN             │ (None, 48, 48, 96)        │             384 │ block_1_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_expand_relu (ReLU)    │ (None, 48, 48, 96)        │               0 │ block_1_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_pad (ZeroPadding2D)   │ (None, 49, 49, 96)        │               0 │ block_1_expand_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_depthwise             │ (None, 24, 24, 96)        │             864 │ block_1_pad[0][0]          │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_depthwise_BN          │ (None, 24, 24, 96)        │             384 │ block_1_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_depthwise_relu (ReLU) │ (None, 24, 24, 96)        │               0 │ block_1_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_project (Conv2D)      │ (None, 24, 24, 24)        │           2,304 │ block_1_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_1_project_BN            │ (None, 24, 24, 24)        │              96 │ block_1_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_expand (Conv2D)       │ (None, 24, 24, 144)       │           3,456 │ block_1_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_expand_BN             │ (None, 24, 24, 144)       │             576 │ block_2_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_expand_relu (ReLU)    │ (None, 24, 24, 144)       │               0 │ block_2_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_depthwise             │ (None, 24, 24, 144)       │           1,296 │ block_2_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_depthwise_BN          │ (None, 24, 24, 144)       │             576 │ block_2_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_depthwise_relu (ReLU) │ (None, 24, 24, 144)       │               0 │ block_2_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_project (Conv2D)      │ (None, 24, 24, 24)        │           3,456 │ block_2_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_project_BN            │ (None, 24, 24, 24)        │              96 │ block_2_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_2_add (Add)             │ (None, 24, 24, 24)        │               0 │ block_1_project_BN[0][0],  │
# │                               │                           │                 │ block_2_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_expand (Conv2D)       │ (None, 24, 24, 144)       │           3,456 │ block_2_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_expand_BN             │ (None, 24, 24, 144)       │             576 │ block_3_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_expand_relu (ReLU)    │ (None, 24, 24, 144)       │               0 │ block_3_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_pad (ZeroPadding2D)   │ (None, 25, 25, 144)       │               0 │ block_3_expand_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_depthwise             │ (None, 12, 12, 144)       │           1,296 │ block_3_pad[0][0]          │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_depthwise_BN          │ (None, 12, 12, 144)       │             576 │ block_3_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_depthwise_relu (ReLU) │ (None, 12, 12, 144)       │               0 │ block_3_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_project (Conv2D)      │ (None, 12, 12, 32)        │           4,608 │ block_3_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_3_project_BN            │ (None, 12, 12, 32)        │             128 │ block_3_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_expand (Conv2D)       │ (None, 12, 12, 192)       │           6,144 │ block_3_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_expand_BN             │ (None, 12, 12, 192)       │             768 │ block_4_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_expand_relu (ReLU)    │ (None, 12, 12, 192)       │               0 │ block_4_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_depthwise             │ (None, 12, 12, 192)       │           1,728 │ block_4_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_depthwise_BN          │ (None, 12, 12, 192)       │             768 │ block_4_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_depthwise_relu (ReLU) │ (None, 12, 12, 192)       │               0 │ block_4_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_project (Conv2D)      │ (None, 12, 12, 32)        │           6,144 │ block_4_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_project_BN            │ (None, 12, 12, 32)        │             128 │ block_4_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_4_add (Add)             │ (None, 12, 12, 32)        │               0 │ block_3_project_BN[0][0],  │
# │                               │                           │                 │ block_4_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_expand (Conv2D)       │ (None, 12, 12, 192)       │           6,144 │ block_4_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_expand_BN             │ (None, 12, 12, 192)       │             768 │ block_5_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_expand_relu (ReLU)    │ (None, 12, 12, 192)       │               0 │ block_5_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_depthwise             │ (None, 12, 12, 192)       │           1,728 │ block_5_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_depthwise_BN          │ (None, 12, 12, 192)       │             768 │ block_5_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_depthwise_relu (ReLU) │ (None, 12, 12, 192)       │               0 │ block_5_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_project (Conv2D)      │ (None, 12, 12, 32)        │           6,144 │ block_5_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_project_BN            │ (None, 12, 12, 32)        │             128 │ block_5_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_5_add (Add)             │ (None, 12, 12, 32)        │               0 │ block_4_add[0][0],         │
# │                               │                           │                 │ block_5_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_expand (Conv2D)       │ (None, 12, 12, 192)       │           6,144 │ block_5_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_expand_BN             │ (None, 12, 12, 192)       │             768 │ block_6_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_expand_relu (ReLU)    │ (None, 12, 12, 192)       │               0 │ block_6_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_pad (ZeroPadding2D)   │ (None, 13, 13, 192)       │               0 │ block_6_expand_relu[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_depthwise             │ (None, 6, 6, 192)         │           1,728 │ block_6_pad[0][0]          │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_depthwise_BN          │ (None, 6, 6, 192)         │             768 │ block_6_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_depthwise_relu (ReLU) │ (None, 6, 6, 192)         │               0 │ block_6_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_project (Conv2D)      │ (None, 6, 6, 64)          │          12,288 │ block_6_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_6_project_BN            │ (None, 6, 6, 64)          │             256 │ block_6_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_expand (Conv2D)       │ (None, 6, 6, 384)         │          24,576 │ block_6_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_expand_BN             │ (None, 6, 6, 384)         │           1,536 │ block_7_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_expand_relu (ReLU)    │ (None, 6, 6, 384)         │               0 │ block_7_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_depthwise             │ (None, 6, 6, 384)         │           3,456 │ block_7_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_depthwise_BN          │ (None, 6, 6, 384)         │           1,536 │ block_7_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_depthwise_relu (ReLU) │ (None, 6, 6, 384)         │               0 │ block_7_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_project (Conv2D)      │ (None, 6, 6, 64)          │          24,576 │ block_7_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_project_BN            │ (None, 6, 6, 64)          │             256 │ block_7_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_7_add (Add)             │ (None, 6, 6, 64)          │               0 │ block_6_project_BN[0][0],  │
# │                               │                           │                 │ block_7_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_expand (Conv2D)       │ (None, 6, 6, 384)         │          24,576 │ block_7_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_expand_BN             │ (None, 6, 6, 384)         │           1,536 │ block_8_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_expand_relu (ReLU)    │ (None, 6, 6, 384)         │               0 │ block_8_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_depthwise             │ (None, 6, 6, 384)         │           3,456 │ block_8_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_depthwise_BN          │ (None, 6, 6, 384)         │           1,536 │ block_8_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_depthwise_relu (ReLU) │ (None, 6, 6, 384)         │               0 │ block_8_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_project (Conv2D)      │ (None, 6, 6, 64)          │          24,576 │ block_8_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_project_BN            │ (None, 6, 6, 64)          │             256 │ block_8_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_8_add (Add)             │ (None, 6, 6, 64)          │               0 │ block_7_add[0][0],         │
# │                               │                           │                 │ block_8_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_expand (Conv2D)       │ (None, 6, 6, 384)         │          24,576 │ block_8_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_expand_BN             │ (None, 6, 6, 384)         │           1,536 │ block_9_expand[0][0]       │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_expand_relu (ReLU)    │ (None, 6, 6, 384)         │               0 │ block_9_expand_BN[0][0]    │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_depthwise             │ (None, 6, 6, 384)         │           3,456 │ block_9_expand_relu[0][0]  │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_depthwise_BN          │ (None, 6, 6, 384)         │           1,536 │ block_9_depthwise[0][0]    │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_depthwise_relu (ReLU) │ (None, 6, 6, 384)         │               0 │ block_9_depthwise_BN[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_project (Conv2D)      │ (None, 6, 6, 64)          │          24,576 │ block_9_depthwise_relu[0]… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_project_BN            │ (None, 6, 6, 64)          │             256 │ block_9_project[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_9_add (Add)             │ (None, 6, 6, 64)          │               0 │ block_8_add[0][0],         │
# │                               │                           │                 │ block_9_project_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_expand (Conv2D)      │ (None, 6, 6, 384)         │          24,576 │ block_9_add[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_expand_BN            │ (None, 6, 6, 384)         │           1,536 │ block_10_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_expand_relu (ReLU)   │ (None, 6, 6, 384)         │               0 │ block_10_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_depthwise            │ (None, 6, 6, 384)         │           3,456 │ block_10_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_depthwise_BN         │ (None, 6, 6, 384)         │           1,536 │ block_10_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_depthwise_relu       │ (None, 6, 6, 384)         │               0 │ block_10_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_project (Conv2D)     │ (None, 6, 6, 96)          │          36,864 │ block_10_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_10_project_BN           │ (None, 6, 6, 96)          │             384 │ block_10_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_expand (Conv2D)      │ (None, 6, 6, 576)         │          55,296 │ block_10_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_expand_BN            │ (None, 6, 6, 576)         │           2,304 │ block_11_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_expand_relu (ReLU)   │ (None, 6, 6, 576)         │               0 │ block_11_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_depthwise            │ (None, 6, 6, 576)         │           5,184 │ block_11_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_depthwise_BN         │ (None, 6, 6, 576)         │           2,304 │ block_11_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_depthwise_relu       │ (None, 6, 6, 576)         │               0 │ block_11_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_project (Conv2D)     │ (None, 6, 6, 96)          │          55,296 │ block_11_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_project_BN           │ (None, 6, 6, 96)          │             384 │ block_11_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_11_add (Add)            │ (None, 6, 6, 96)          │               0 │ block_10_project_BN[0][0], │
# │                               │                           │                 │ block_11_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_expand (Conv2D)      │ (None, 6, 6, 576)         │          55,296 │ block_11_add[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_expand_BN            │ (None, 6, 6, 576)         │           2,304 │ block_12_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_expand_relu (ReLU)   │ (None, 6, 6, 576)         │               0 │ block_12_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_depthwise            │ (None, 6, 6, 576)         │           5,184 │ block_12_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_depthwise_BN         │ (None, 6, 6, 576)         │           2,304 │ block_12_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_depthwise_relu       │ (None, 6, 6, 576)         │               0 │ block_12_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_project (Conv2D)     │ (None, 6, 6, 96)          │          55,296 │ block_12_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_project_BN           │ (None, 6, 6, 96)          │             384 │ block_12_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_12_add (Add)            │ (None, 6, 6, 96)          │               0 │ block_11_add[0][0],        │
# │                               │                           │                 │ block_12_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_expand (Conv2D)      │ (None, 6, 6, 576)         │          55,296 │ block_12_add[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_expand_BN            │ (None, 6, 6, 576)         │           2,304 │ block_13_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_expand_relu (ReLU)   │ (None, 6, 6, 576)         │               0 │ block_13_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_pad (ZeroPadding2D)  │ (None, 7, 7, 576)         │               0 │ block_13_expand_relu[0][0] │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_depthwise            │ (None, 3, 3, 576)         │           5,184 │ block_13_pad[0][0]         │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_depthwise_BN         │ (None, 3, 3, 576)         │           2,304 │ block_13_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_depthwise_relu       │ (None, 3, 3, 576)         │               0 │ block_13_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_project (Conv2D)     │ (None, 3, 3, 160)         │          92,160 │ block_13_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_13_project_BN           │ (None, 3, 3, 160)         │             640 │ block_13_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_expand (Conv2D)      │ (None, 3, 3, 960)         │         153,600 │ block_13_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_expand_BN            │ (None, 3, 3, 960)         │           3,840 │ block_14_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_expand_relu (ReLU)   │ (None, 3, 3, 960)         │               0 │ block_14_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_depthwise            │ (None, 3, 3, 960)         │           8,640 │ block_14_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_depthwise_BN         │ (None, 3, 3, 960)         │           3,840 │ block_14_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_depthwise_relu       │ (None, 3, 3, 960)         │               0 │ block_14_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_project (Conv2D)     │ (None, 3, 3, 160)         │         153,600 │ block_14_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_project_BN           │ (None, 3, 3, 160)         │             640 │ block_14_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_14_add (Add)            │ (None, 3, 3, 160)         │               0 │ block_13_project_BN[0][0], │
# │                               │                           │                 │ block_14_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_expand (Conv2D)      │ (None, 3, 3, 960)         │         153,600 │ block_14_add[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_expand_BN            │ (None, 3, 3, 960)         │           3,840 │ block_15_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_expand_relu (ReLU)   │ (None, 3, 3, 960)         │               0 │ block_15_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_depthwise            │ (None, 3, 3, 960)         │           8,640 │ block_15_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_depthwise_BN         │ (None, 3, 3, 960)         │           3,840 │ block_15_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_depthwise_relu       │ (None, 3, 3, 960)         │               0 │ block_15_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_project (Conv2D)     │ (None, 3, 3, 160)         │         153,600 │ block_15_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_project_BN           │ (None, 3, 3, 160)         │             640 │ block_15_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_15_add (Add)            │ (None, 3, 3, 160)         │               0 │ block_14_add[0][0],        │
# │                               │                           │                 │ block_15_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_expand (Conv2D)      │ (None, 3, 3, 960)         │         153,600 │ block_15_add[0][0]         │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_expand_BN            │ (None, 3, 3, 960)         │           3,840 │ block_16_expand[0][0]      │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_expand_relu (ReLU)   │ (None, 3, 3, 960)         │               0 │ block_16_expand_BN[0][0]   │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_depthwise            │ (None, 3, 3, 960)         │           8,640 │ block_16_expand_relu[0][0] │
# │ (DepthwiseConv2D)             │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_depthwise_BN         │ (None, 3, 3, 960)         │           3,840 │ block_16_depthwise[0][0]   │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_depthwise_relu       │ (None, 3, 3, 960)         │               0 │ block_16_depthwise_BN[0][… │
# │ (ReLU)                        │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_project (Conv2D)     │ (None, 3, 3, 320)         │         307,200 │ block_16_depthwise_relu[0… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ block_16_project_BN           │ (None, 3, 3, 320)         │           1,280 │ block_16_project[0][0]     │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv_1 (Conv2D)               │ (None, 3, 3, 1280)        │         409,600 │ block_16_project_BN[0][0]  │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ Conv_1_bn                     │ (None, 3, 3, 1280)        │           5,120 │ Conv_1[0][0]               │
# │ (BatchNormalization)          │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ out_relu (ReLU)               │ (None, 3, 3, 1280)        │               0 │ Conv_1_bn[0][0]            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ global_average_pooling2d      │ (None, 1280)              │               0 │ out_relu[0][0]             │
# │ (GlobalAveragePooling2D)      │                           │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 128)               │         163,968 │ global_average_pooling2d[… │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dropout (Dropout)             │ (None, 128)               │               0 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 5)                 │             645 │ dropout[0][0]              │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 2,422,597 (9.24 MB)
#  Trainable params: 164,613 (643.02 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %%
# Cell 4: Class Weights & Early Stopping
from sklearn.utils import class_weight
from tensorflow.keras.callbacks import EarlyStopping

# Convert back to original labels for class weight computation
y_train_labels = np.argmax(y_train, axis=1)
weights = class_weight.compute_class_weight(class_weight='balanced',
                                             classes=np.unique(y_train_labels),
                                             y=y_train_labels)
class_weights = {i: w for i, w in enumerate(weights)}
print("Class weights:", class_weights)

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
# Out:
# Class weights: {0: 1.2034364261168384, 1: 0.8733167082294264, 2: 1.2075862068965517, 3: 0.9119791666666667, 4: 0.9096103896103896}

# %%
# Cell 5: Model Training
history = model.fit(
    datagen.flow(X_train, y_train, batch_size=32),
    validation_data=(X_test, y_test),
    epochs=30,
    callbacks=[early_stop],
    class_weight=class_weights,
    verbose=1
)
# Out:
# C:\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 33s 360ms/step - accuracy: 0.2738 - loss: 0.0816 - val_accuracy: 0.5023 - val_loss: 0.0355
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 281ms/step - accuracy: 0.4214 - loss: 0.0452 - val_accuracy: 0.5959 - val_loss: 0.0280
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 279ms/step - accuracy: 0.5355 - loss: 0.0346 - val_accuracy: 0.6507 - val_loss: 0.0248
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 280ms/step - accuracy: 0.5557 - loss: 0.0296 - val_accuracy: 0.6689 - val_loss: 0.0228
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 281ms/step - accuracy: 0.6047 - loss: 0.0258 - val_accuracy: 0.6849 - val_loss: 0.0206
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 277ms/step - accuracy: 0.6293 - loss: 0.0244 - val_accuracy: 0.7237 - val_loss: 0.0190
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 291ms/step - accuracy: 0.6789 - loss: 0.0219 - val_accuracy: 0.7169 - val_loss: 0.0182
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 291ms/step - accuracy: 0.6612 - loss: 0.0212 - val_accuracy: 0.7329 - val_loss: 0.0176
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 280ms/step - accuracy: 0.7152 - loss: 0.0204 - val_accuracy: 0.7443 - val_loss: 0.0170
# Epoch 10/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 277ms/step - accuracy: 0.7073 - loss: 0.0181 - val_accuracy: 0.7648 - val_loss: 0.0164
# Epoch 11/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 277ms/step - accuracy: 0.7229 - loss: 0.0161 - val_accuracy: 0.7671 - val_loss: 0.0162
# Epoch 12/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 286ms/step - accuracy: 0.7152 - loss: 0.0170 - val_accuracy: 0.7785 - val_loss: 0.0155
# Epoch 13/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 277ms/step - accuracy: 0.7380 - loss: 0.0161 - val_accuracy: 0.7671 - val_loss: 0.0159
# Epoch 14/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 286ms/step - accuracy: 0.7496 - loss: 0.0150 - val_accuracy: 0.7808 - val_loss: 0.0147
# Epoch 15/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 283ms/step - accuracy: 0.7444 - loss: 0.0155 - val_accuracy: 0.7854 - val_loss: 0.0146
# Epoch 16/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 284ms/step - accuracy: 0.7465 - loss: 0.0143 - val_accuracy: 0.7945 - val_loss: 0.0145
# Epoch 17/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 277ms/step - accuracy: 0.7608 - loss: 0.0149 - val_accuracy: 0.7991 - val_loss: 0.0141
# Epoch 18/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 277ms/step - accuracy: 0.7713 - loss: 0.0128 - val_accuracy: 0.7991 - val_loss: 0.0141
# Epoch 19/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 280ms/step - accuracy: 0.7831 - loss: 0.0121 - val_accuracy: 0.8037 - val_loss: 0.0139
# Epoch 20/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 281ms/step - accuracy: 0.8043 - loss: 0.0114 - val_accuracy: 0.8082 - val_loss: 0.0141
# Epoch 21/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 277ms/step - accuracy: 0.7789 - loss: 0.0125 - val_accuracy: 0.8037 - val_loss: 0.0140
# Epoch 22/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 17s 303ms/step - accuracy: 0.7935 - loss: 0.0112 - val_accuracy: 0.7968 - val_loss: 0.0141
# Epoch 23/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 288ms/step - accuracy: 0.8072 - loss: 0.0112 - val_accuracy: 0.7991 - val_loss: 0.0139
# Epoch 24/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 15s 279ms/step - accuracy: 0.8165 - loss: 0.0101 - val_accuracy: 0.7877 - val_loss: 0.0140

# %%
# Cell 6: Plot Accuracy & Loss
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.legend()
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.legend()
plt.title('Loss')
plt.show()

# %%
# Cell 7: Evaluation & Classification Report
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {test_acc*100:.2f}%")

y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

print(classification_report(y_true_labels, y_pred_labels, target_names=le.classes_))

cm = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Test Accuracy: 80.37%
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 7s 343ms/step
#               precision    recall  f1-score   support
#
#    cardboard       0.87      0.92      0.89        73
#        glass       0.79      0.68      0.73       100
#        metal       0.68      0.92      0.78        72
#        paper       0.84      0.84      0.84        96
#      plastic       0.85      0.72      0.78        97
#
#     accuracy                           0.80       438
#    macro avg       0.81      0.82      0.81       438
# weighted avg       0.81      0.80      0.80       438

# %%
import os

dataset_path = "dataset-resized"  # make sure this path is correct
class_counts = {}

for class_name in os.listdir(dataset_path):
    class_dir = os.path.join(dataset_path, class_name)
    if os.path.isdir(class_dir):
        image_count = len([f for f in os.listdir(class_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
        class_counts[class_name] = image_count

print(class_counts)
# Out:
# {'cardboard': 364, 'glass': 501, 'metal': 362, 'paper': 480, 'plastic': 482, 'trash': 137}

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Enhanced augmentation to improve generalization and class balance support
datagen = ImageDataGenerator(
    rotation_range=25,
    width_shift_range=0.15,
    height_shift_range=0.15,
    shear_range=0.1,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

datagen.fit(X_train)

# %%
import tensorflow as tf
import tensorflow.keras.backend as K
from tensorflow.keras.losses import Loss

class FocalLoss(Loss):
    def __init__(self, gamma=2., alpha=0.25):
        super().__init__()
        self.gamma = gamma
        self.alpha = alpha

    def call(self, y_true, y_pred):
        epsilon = K.epsilon()
        y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
        cross_entropy = -y_true * K.log(y_pred)
        weight = self.alpha * K.pow(1 - y_pred, self.gamma)
        return K.mean(weight * cross_entropy, axis=-1)

# Re-compile the model with Focal Loss
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
              loss=FocalLoss(gamma=2.0, alpha=0.25),
              metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Reduce LR when a metric has stopped improving
lr_reducer = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                               patience=3, min_lr=1e-6, verbose=1)

# Retrain
history2 = model.fit(
    datagen.flow(X_train, y_train, batch_size=32),
    validation_data=(X_test, y_test),
    epochs=30,
    callbacks=[early_stop, lr_reducer],
    class_weight=class_weights,
    verbose=1
)
# Out:
# C:\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 33s 372ms/step - accuracy: 0.7645 - loss: 0.0136 - val_accuracy: 0.7968 - val_loss: 0.0140 - learning_rate: 1.0000e-04
# Epoch 2/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 17s 302ms/step - accuracy: 0.7537 - loss: 0.0146 - val_accuracy: 0.8014 - val_loss: 0.0139 - learning_rate: 1.0000e-04
# Epoch 3/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 291ms/step - accuracy: 0.7744 - loss: 0.0136 - val_accuracy: 0.7968 - val_loss: 0.0140 - learning_rate: 1.0000e-04
# Epoch 4/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 298ms/step - accuracy: 0.7826 - loss: 0.0122 - val_accuracy: 0.7991 - val_loss: 0.0138 - learning_rate: 1.0000e-04
# Epoch 5/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 17s 301ms/step - accuracy: 0.8054 - loss: 0.0122 - val_accuracy: 0.7991 - val_loss: 0.0137 - learning_rate: 1.0000e-04
# Epoch 6/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 17s 304ms/step - accuracy: 0.8004 - loss: 0.0116 - val_accuracy: 0.8014 - val_loss: 0.0135 - learning_rate: 1.0000e-04
# Epoch 7/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 297ms/step - accuracy: 0.7764 - loss: 0.0116 - val_accuracy: 0.8037 - val_loss: 0.0136 - learning_rate: 1.0000e-04
# Epoch 8/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 289ms/step - accuracy: 0.7964 - loss: 0.0124 - val_accuracy: 0.8105 - val_loss: 0.0130 - learning_rate: 1.0000e-04
# Epoch 9/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 285ms/step - accuracy: 0.8083 - loss: 0.0120 - val_accuracy: 0.7968 - val_loss: 0.0131 - learning_rate: 1.0000e-04
# Epoch 10/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 287ms/step - accuracy: 0.7996 - loss: 0.0113 - val_accuracy: 0.8037 - val_loss: 0.0130 - learning_rate: 1.0000e-04
# Epoch 11/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 293ms/step - accuracy: 0.8194 - loss: 0.0101 - val_accuracy: 0.8151 - val_loss: 0.0127 - learning_rate: 1.0000e-04
# Epoch 12/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 289ms/step - accuracy: 0.8090 - loss: 0.0106 - val_accuracy: 0.8014 - val_loss: 0.0134 - learning_rate: 1.0000e-04
# Epoch 13/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 289ms/step - accuracy: 0.8363 - loss: 0.0098 - val_accuracy: 0.8037 - val_loss: 0.0132 - learning_rate: 1.0000e-04
# Epoch 14/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.7882 - loss: 0.0114
# Epoch 14: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 295ms/step - accuracy: 0.7884 - loss: 0.0114 - val_accuracy: 0.7968 - val_loss: 0.0130 - learning_rate: 1.0000e-04
# Epoch 15/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 282ms/step - accuracy: 0.8112 - loss: 0.0097 - val_accuracy: 0.8105 - val_loss: 0.0130 - learning_rate: 5.0000e-05
# Epoch 16/30
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 285ms/step - accuracy: 0.8376 - loss: 0.0096 - val_accuracy: 0.8128 - val_loss: 0.0131 - learning_rate: 5.0000e-05

# %%
# Re-evaluate and plot updated metrics
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"✅ Updated Test Accuracy: {test_acc * 100:.2f}%")

y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_true_labels, y_pred_labels, target_names=le.classes_))

import seaborn as sns
import matplotlib.pyplot as plt
cm = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(6, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Updated Confusion Matrix")
plt.show()
# Out:
# ✅ Updated Test Accuracy: 81.51%
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step
#               precision    recall  f1-score   support
#
#    cardboard       0.87      0.95      0.91        73
#        glass       0.81      0.72      0.76       100
#        metal       0.70      0.90      0.79        72
#        paper       0.87      0.83      0.85        96
#      plastic       0.84      0.73      0.78        97
#
#     accuracy                           0.82       438
#    macro avg       0.82      0.83      0.82       438
# weighted avg       0.82      0.82      0.81       438

# %%
# A: Oversample underrepresented classes in memory
from collections import Counter
from sklearn.utils import resample

# Decode one-hot back to class indices
y_labels = np.argmax(y_train, axis=1)
X_aug = []
y_aug = []

# Find max class count
counts = Counter(y_labels)
max_count = max(counts.values())

for cls in np.unique(y_labels):
    cls_indices = np.where(y_labels == cls)[0]
    X_cls = X_train[cls_indices]
    y_cls = y_train[cls_indices]
    
    X_upsampled, y_upsampled = resample(X_cls, y_cls,
                                        replace=True,
                                        n_samples=max_count,
                                        random_state=42)
    X_aug.append(X_upsampled)
    y_aug.append(y_upsampled)

# Concatenate all oversampled data
X_train_balanced = np.concatenate(X_aug)
y_train_balanced = np.concatenate(y_aug)

print("New training shape:", X_train_balanced.shape, y_train_balanced.shape)
# Out:
# New training shape: (2005, 96, 96, 3) (2005, 5)

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Define learning rate reducer callback
lr_reduce = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    verbose=1,
    min_lr=1e-6
)

# %%
# B: Retrain using balanced data
history_balanced = model.fit(
    datagen.flow(X_train_balanced, y_train_balanced, batch_size=32),
    validation_data=(X_test, y_test),
    epochs=30,
    callbacks=[early_stop, lr_reduce],
    verbose=1
)
# Out:
# C:\Python312\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 25s 297ms/step - accuracy: 0.8352 - loss: 0.0110 - val_accuracy: 0.8014 - val_loss: 0.0133 - learning_rate: 5.0000e-05
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 289ms/step - accuracy: 0.8254 - loss: 0.0111 - val_accuracy: 0.8037 - val_loss: 0.0134 - learning_rate: 5.0000e-05
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 290ms/step - accuracy: 0.8141 - loss: 0.0112 - val_accuracy: 0.8059 - val_loss: 0.0133 - learning_rate: 5.0000e-05
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 19s 294ms/step - accuracy: 0.8287 - loss: 0.0099 - val_accuracy: 0.8128 - val_loss: 0.0131 - learning_rate: 5.0000e-05
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 285ms/step - accuracy: 0.8393 - loss: 0.0100 - val_accuracy: 0.8037 - val_loss: 0.0134 - learning_rate: 5.0000e-05
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 21s 295ms/step - accuracy: 0.8509 - loss: 0.0088 - val_accuracy: 0.8082 - val_loss: 0.0130 - learning_rate: 5.0000e-05
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 283ms/step - accuracy: 0.8309 - loss: 0.0092 - val_accuracy: 0.8059 - val_loss: 0.0133 - learning_rate: 5.0000e-05
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 281ms/step - accuracy: 0.8398 - loss: 0.0086 - val_accuracy: 0.8059 - val_loss: 0.0134 - learning_rate: 5.0000e-05
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.8595 - loss: 0.0084
# Epoch 9: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 279ms/step - accuracy: 0.8592 - loss: 0.0084 - val_accuracy: 0.8059 - val_loss: 0.0132 - learning_rate: 5.0000e-05
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 19s 293ms/step - accuracy: 0.8477 - loss: 0.0090 - val_accuracy: 0.8105 - val_loss: 0.0132 - learning_rate: 2.5000e-05
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 18s 287ms/step - accuracy: 0.8509 - loss: 0.0082 - val_accuracy: 0.8059 - val_loss: 0.0132 - learning_rate: 2.5000e-05

# %%
# C: Evaluate again
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=0)
print(f"🎯 New Test Accuracy after oversampling: {test_acc * 100:.2f}%")
# Out:
# 🎯 New Test Accuracy after oversampling: 80.82%

# %%
model.save("model/final1_material_model.keras")
print("model saved")
# Out:
# model saved

# %%
from sklearn.preprocessing import LabelEncoder
import joblib
import os

# Define class names in the correct order
class_names = ['cardboard', 'glass', 'metal', 'paper', 'plastic']

# Fit the LabelEncoder
le = LabelEncoder()
le.fit(class_names)

# Ensure model directory exists
os.makedirs("model", exist_ok=True)

# Save the encoder
joblib.dump(le, "model/label_encoder.pkl")

# Optional: print classes to verify
print("Classes saved in label encoder:", le.classes_)
# Out:
# Classes saved in label encoder: ['cardboard' 'glass' 'metal' 'paper' 'plastic']

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Step 1: Define class names
class_names = ['cardboard', 'glass', 'metal', 'paper', 'plastic']

# Step 2: Fit LabelEncoder
le = LabelEncoder()
le.fit(class_names)

# Step 3: Decode y_train back to string labels
y_train_labels = le.inverse_transform(np.argmax(y_train, axis=1))

# Step 4: Compute class weights (convert classes to np.array)
class_weights = compute_class_weight(class_weight='balanced', classes=np.array(class_names), y=y_train_labels)
class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

print("Class weights:", class_weight_dict)
# Out:
# Class weights: {0: 1.2034364261168384, 1: 0.8733167082294264, 2: 1.2075862068965517, 3: 0.9119791666666667, 4: 0.9096103896103896}

# %%
for i, layer in enumerate(model.layers):
    print(i, layer.name, layer.__class__.__name__)
# Out:
# 0 input_layer InputLayer
# 1 Conv1 Conv2D
# 2 bn_Conv1 BatchNormalization
# 3 Conv1_relu ReLU
# 4 expanded_conv_depthwise DepthwiseConv2D
# 5 expanded_conv_depthwise_BN BatchNormalization
# 6 expanded_conv_depthwise_relu ReLU
# 7 expanded_conv_project Conv2D
# 8 expanded_conv_project_BN BatchNormalization
# 9 block_1_expand Conv2D
# 10 block_1_expand_BN BatchNormalization
# 11 block_1_expand_relu ReLU
# 12 block_1_pad ZeroPadding2D
# 13 block_1_depthwise DepthwiseConv2D
# 14 block_1_depthwise_BN BatchNormalization
# 15 block_1_depthwise_relu ReLU
# 16 block_1_project Conv2D
# 17 block_1_project_BN BatchNormalization
# 18 block_2_expand Conv2D
# 19 block_2_expand_BN BatchNormalization
# 20 block_2_expand_relu ReLU
# 21 block_2_depthwise DepthwiseConv2D
# 22 block_2_depthwise_BN BatchNormalization
# 23 block_2_depthwise_relu ReLU
# 24 block_2_project Conv2D
# 25 block_2_project_BN BatchNormalization
# 26 block_2_add Add
# 27 block_3_expand Conv2D
# 28 block_3_expand_BN BatchNormalization
# 29 block_3_expand_relu ReLU
# 30 block_3_pad ZeroPadding2D
# 31 block_3_depthwise DepthwiseConv2D
# 32 block_3_depthwise_BN BatchNormalization
# 33 block_3_depthwise_relu ReLU
# 34 block_3_project Conv2D
# 35 block_3_project_BN BatchNormalization
# 36 block_4_expand Conv2D
# 37 block_4_expand_BN BatchNormalization
# 38 block_4_expand_relu ReLU
# 39 block_4_depthwise DepthwiseConv2D
# 40 block_4_depthwise_BN BatchNormalization
# 41 block_4_depthwise_relu ReLU
# 42 block_4_project Conv2D
# 43 block_4_project_BN BatchNormalization
# 44 block_4_add Add
# 45 block_5_expand Conv2D
# 46 block_5_expand_BN BatchNormalization
# 47 block_5_expand_relu ReLU
# 48 block_5_depthwise DepthwiseConv2D
# 49 block_5_depthwise_BN BatchNormalization
# 50 block_5_depthwise_relu ReLU
# 51 block_5_project Conv2D
# 52 block_5_project_BN BatchNormalization
# 53 block_5_add Add
# 54 block_6_expand Conv2D
# 55 block_6_expand_BN BatchNormalization
# 56 block_6_expand_relu ReLU
# 57 block_6_pad ZeroPadding2D
# 58 block_6_depthwise DepthwiseConv2D
# 59 block_6_depthwise_BN BatchNormalization
# 60 block_6_depthwise_relu ReLU
# 61 block_6_project Conv2D
# 62 block_6_project_BN BatchNormalization
# 63 block_7_expand Conv2D
# 64 block_7_expand_BN BatchNormalization
# 65 block_7_expand_relu ReLU
# 66 block_7_depthwise DepthwiseConv2D
# 67 block_7_depthwise_BN BatchNormalization
# 68 block_7_depthwise_relu ReLU
# 69 block_7_project Conv2D
# 70 block_7_project_BN BatchNormalization
# 71 block_7_add Add
# 72 block_8_expand Conv2D
# 73 block_8_expand_BN BatchNormalization
# 74 block_8_expand_relu ReLU
# 75 block_8_depthwise DepthwiseConv2D
# 76 block_8_depthwise_BN BatchNormalization
# 77 block_8_depthwise_relu ReLU
# 78 block_8_project Conv2D
# 79 block_8_project_BN BatchNormalization
# 80 block_8_add Add
# 81 block_9_expand Conv2D
# 82 block_9_expand_BN BatchNormalization
# 83 block_9_expand_relu ReLU
# 84 block_9_depthwise DepthwiseConv2D
# 85 block_9_depthwise_BN BatchNormalization
# 86 block_9_depthwise_relu ReLU
# 87 block_9_project Conv2D
# 88 block_9_project_BN BatchNormalization
# 89 block_9_add Add
# 90 block_10_expand Conv2D
# 91 block_10_expand_BN BatchNormalization
# 92 block_10_expand_relu ReLU
# 93 block_10_depthwise DepthwiseConv2D
# 94 block_10_depthwise_BN BatchNormalization
# 95 block_10_depthwise_relu ReLU
# 96 block_10_project Conv2D
# 97 block_10_project_BN BatchNormalization
# 98 block_11_expand Conv2D
# 99 block_11_expand_BN BatchNormalization
# 100 block_11_expand_relu ReLU
# 101 block_11_depthwise DepthwiseConv2D
# 102 block_11_depthwise_BN BatchNormalization
# 103 block_11_depthwise_relu ReLU
# 104 block_11_project Conv2D
# 105 block_11_project_BN BatchNormalization
# 106 block_11_add Add
# 107 block_12_expand Conv2D
# 108 block_12_expand_BN BatchNormalization
# 109 block_12_expand_relu ReLU
# 110 block_12_depthwise DepthwiseConv2D
# 111 block_12_depthwise_BN BatchNormalization
# 112 block_12_depthwise_relu ReLU
# 113 block_12_project Conv2D
# 114 block_12_project_BN BatchNormalization
# 115 block_12_add Add
# 116 block_13_expand Conv2D
# 117 block_13_expand_BN BatchNormalization
# 118 block_13_expand_relu ReLU
# 119 block_13_pad ZeroPadding2D
# 120 block_13_depthwise DepthwiseConv2D
# 121 block_13_depthwise_BN BatchNormalization
# 122 block_13_depthwise_relu ReLU
# 123 block_13_project Conv2D
# 124 block_13_project_BN BatchNormalization
# 125 block_14_expand Conv2D
# 126 block_14_expand_BN BatchNormalization
# 127 block_14_expand_relu ReLU
# 128 block_14_depthwise DepthwiseConv2D
# 129 block_14_depthwise_BN BatchNormalization
# 130 block_14_depthwise_relu ReLU
# 131 block_14_project Conv2D
# 132 block_14_project_BN BatchNormalization
# 133 block_14_add Add
# 134 block_15_expand Conv2D
# 135 block_15_expand_BN BatchNormalization
# 136 block_15_expand_relu ReLU
# 137 block_15_depthwise DepthwiseConv2D
# 138 block_15_depthwise_BN BatchNormalization
# 139 block_15_depthwise_relu ReLU
# 140 block_15_project Conv2D
# 141 block_15_project_BN BatchNormalization
# 142 block_15_add Add
# 143 block_16_expand Conv2D
# 144 block_16_expand_BN BatchNormalization
# 145 block_16_expand_relu ReLU
# 146 block_16_depthwise DepthwiseConv2D
# 147 block_16_depthwise_BN BatchNormalization
# 148 block_16_depthwise_relu ReLU
# 149 block_16_project Conv2D
# 150 block_16_project_BN BatchNormalization
# 151 Conv_1 Conv2D
# 152 Conv_1_bn BatchNormalization
# 153 out_relu ReLU
# 154 global_average_pooling2d GlobalAveragePooling2D
# 155 dense Dense
# 156 dropout Dropout
# 157 dense_1 Dense

# %%
# Targeted reweighting and training for 'metal' class using a custom sample generator

import numpy as np

# Step 1: Augment the 'metal' class
metal_index = np.argmax(y_train, axis=1) == le.transform(['metal'])[0]
X_metal = X_train[metal_index]
y_metal = y_train[metal_index]

X_augmented = np.concatenate([X_train, X_metal, X_metal])
y_augmented = np.concatenate([y_train, y_metal, y_metal])

# Step 2: Convert one-hot to integer labels for sample weights
y_aug_int = np.argmax(y_augmented, axis=1)
sample_weights = np.array([class_weights[int(cls)] for cls in y_aug_int])

# Step 3: Custom generator using correct index tracking
def weighted_generator(x, y, sample_w, batch_size=32):
    gen = datagen.flow(x, y, batch_size=batch_size, shuffle=True)
    sample_w = np.array(sample_w)
    while True:
        x_batch, y_batch = next(gen)
        batch_size_actual = len(x_batch)

        # Use current index in generator
        batch_index = (gen.batch_index - 1) % (gen.n // gen.batch_size + 1)
        index_array = gen.index_array
        start = batch_index * batch_size
        end = start + batch_size_actual
        indices = index_array[start:end]

        yield x_batch, y_batch, sample_w[indices]


# Step 4: Setup training
weighted_gen = weighted_generator(X_augmented, y_augmented, sample_weights, batch_size=32)
steps_per_epoch = len(X_augmented) // 32

history_metal_focus = model.fit(
    weighted_gen,
    validation_data=(X_test, y_test),
    steps_per_epoch=steps_per_epoch,
    epochs=10,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 21s 286ms/step - accuracy: 0.8353 - loss: 0.0098 - val_accuracy: 0.7922 - val_loss: 0.0149
# Epoch 2/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 20s 279ms/step - accuracy: 0.8569 - loss: 0.0088 - val_accuracy: 0.7900 - val_loss: 0.0148
# Epoch 3/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 20s 273ms/step - accuracy: 0.8547 - loss: 0.0087 - val_accuracy: 0.7854 - val_loss: 0.0151
# Epoch 4/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 19s 264ms/step - accuracy: 0.8402 - loss: 0.0093 - val_accuracy: 0.7900 - val_loss: 0.0151
# Epoch 5/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 20s 278ms/step - accuracy: 0.8449 - loss: 0.0089 - val_accuracy: 0.7900 - val_loss: 0.0150
# Epoch 6/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 20s 273ms/step - accuracy: 0.8545 - loss: 0.0088 - val_accuracy: 0.7922 - val_loss: 0.0148
# Epoch 7/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 19s 264ms/step - accuracy: 0.8576 - loss: 0.0084 - val_accuracy: 0.7900 - val_loss: 0.0149
# Epoch 8/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 19s 260ms/step - accuracy: 0.8601 - loss: 0.0079 - val_accuracy: 0.7900 - val_loss: 0.0154
# Epoch 9/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 20s 279ms/step - accuracy: 0.8446 - loss: 0.0086 - val_accuracy: 0.7900 - val_loss: 0.0151
# Epoch 10/10
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 20s 276ms/step - accuracy: 0.8655 - loss: 0.0079 - val_accuracy: 0.7831 - val_loss: 0.0153

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Predict
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Report
print(classification_report(y_true_labels, y_pred_labels, target_names=le.classes_))

# Confusion Matrix
cm = confusion_matrix(y_true_labels, y_pred_labels)
plt.figure(figsize=(6,5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=le.classes_, yticklabels=le.classes_)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Metal Focused Confusion Matrix")
plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 163ms/step
#               precision    recall  f1-score   support
#
#    cardboard       0.89      0.92      0.91        73
#        glass       0.85      0.64      0.73       100
#        metal       0.58      0.96      0.72        72
#        paper       0.88      0.82      0.85        96
#      plastic       0.86      0.70      0.77        97
#
#     accuracy                           0.79       438
#    macro avg       0.81      0.81      0.80       438
# weighted avg       0.82      0.79      0.79       438

# %%
model.save("model/final1_material_model.keras")
print("model saved")
# Out:
# model saved
